# %%
hey

# %%
print("Why don't scientists trust atoms? Because they make up everything!")

# %% [markdown]
# ## New Markdown Cell
#
# This is a new markdown cell added by a command. How can I assist you further?
